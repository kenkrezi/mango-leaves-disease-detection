# %%
import os

with open("new_train.txt", "w+") as f:
    for i in os.listdir("images"):
        f.write(i.split(".")[0]+"\n")
    f.close()

with open("val.txt", "w+") as f:
    for i in os.listdir("images"):
        f.write(i.split(".")[0]+"\n")
    f.close()

with open("trainval.txt", "w+") as f:
    for i in os.listdir("images"):
        f.write(i.split(".")[0]+"\n")
    f.close()
    
with open("new_test.txt", "w+") as f:
    for i in os.listdir("images"):
        f.write(i.split(".")[0]+"\n")
    f.close()

# %%
for i in os.listdir("images"):
    os.rename(os.path.join("images", i), os.path.join("images", i.split('.')[0] + ".jpg"))
    print(os.path.join("images", i.split('.')[0] + ".jpg"))
# Out:
# images/0001_0111.jpg
# images/0012_0040.jpg
# images/0012_0140.jpg
# images/0001_0044.jpg
# images/0012_0151.jpg
# images/0012_0232.jpg
# images/0012_0173.jpg
# images/0012_0206.jpg
# images/0012_0152.jpg
# images/0012_0122.jpg
# images/0012_0030.jpg
# images/0012_0038.jpg
# images/0001_0042.jpg
# images/0001_0122.jpg
# images/0012_0071.jpg
# images/0012_0258.jpg
# images/0012_0127.jpg
# images/0001_0029.jpg
# images/0012_0230.jpg
# images/0012_0181.jpg
# images/0012_0117.jpg
# images/0012_0007.jpg
# images/0001_0110.jpg
# images/0001_0073.jpg
# images/0001_0141.jpg
# images/0012_0145.jpg
# images/0001_0127.jpg
# images/0001_0031.jpg
# images/0012_0134.jpg
# images/0001_0144.jpg
# images/0012_0229.jpg
# images/0001_0038.jpg
# images/0012_0207.jpg
# images/0012_0025.jpg
# images/0012_0220.jpg
# images/0012_0028.jpg
# images/0001_0017.jpg
# images/0001_0069.jpg
# images/0001_0166.jpg
# images/0012_0082.jpg
# images/0012_0217.jpg
# images/0012_0156.jpg
# images/0001_0128.jpg
# ...

# %%
# !pip install shutils
# Out:
# ...
#      |████████████████████████████████| 43 kB 51 kB/s  eta 0:00:01
# ...
#   Created wheel for shutils: filename=shutils-0.1.0-py3-none-any.whl size=3516 sha256=ee7d4926dbcaec1b9b7addc4a056d0160cbba1be1152eda5bde0875439bd7fc9
#   Stored in directory: /home/lodhi/.cache/pip/wheels/5e/00/92/466a27dc20f587b42a7c7354f3b005c12b737dabf1a57cd61c
# Successfully built shutils
# ...
# WARNING: You are using pip version 21.2.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/lodhi/PycharmProjects/SSD_Keras/env_ssd/bin/python -m pip install --upgrade pip' command.
